# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LogisticRegression, LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score, accuracy_score, confusion_matrix, precision_score, recall_score, f1_score
from matplotlib import style
from sklearn.preprocessing import StandardScaler, LabelEncoder
import seaborn as sb
import warnings
from sklearn.datasets import load_iris
from icecream import ic

# %%
warnings.filterwarnings("ignore")

# %% [markdown]
# ## Let's do ETL:

# %%
df = pd.read_csv("Assets/Titanic_Dataset.csv")
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  891.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.308265    0.523008
# std     257.353842    0.486592    0.836071   13.720846    1.102743
# min       1.000000    0.000000    1.000000   -5.491899    0.000000
# 25%     223.500000    0.000000    2.000000   21.000000    0.000000
# 50%     446.000000    0.000000    3.000000   29.000000    0.000000
# 75%     668.500000    1.000000    3.000000   36.993780    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age              0
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
df.drop(columns=["Cabin"], inplace=True) #drop columns which have null values as it will create issues in prediction
ic(df)
# Out:
# ic| df:      PassengerId  Survived  Pclass  \
#         0              1         0       3
#         1              2         1       1
#         2              3         1       3
#         3              4         1       1
#         4              5         0       3
#         ..           ...       ...     ...
#         886          887         0       2
#         887          888         1       1
#         888          889         0       3
#         889          890         1       1
#         890          891         0       3
#
#                                                           Name     Sex        Age  \
#         0                              Braund, Mr. Owen Harris    male  22.000000
#         1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.000000
#         2                               Heikkinen, Miss. Laina  female  26.000000
#         3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.000000
#         4                             Allen, Mr. William Henry    male  35.000000
#         ..                                                 ...     ...        ...
#         886                              Montvila, Rev. Juozas    male  27.000000
#         887                       Graham, Miss. Margaret Edith  female  19.000000
#         888           Johnston, Miss. Catherine Helen "Carrie"  female  23.494303
#         889                              Behr, Mr. Karl Howell    male  26.000000
#         890                                Dooley, Mr. Patrick    male  32.000000
#
#              SibSp  Parch            Ticket     Fare Embarked
#         0        1      0         A/5 21171   7.2500        S
#         1        1      0          PC 17599  71.2833        C
#         2        0      0  STON/O2. 3101282   7.9250        S
#         3        1      0            113803  53.1000        S
#         4        0      0            373450   8.0500        S
#         ..     ...    ...               ...      ...      ...
#         886      0      0            211536  13.0000        S
#         887      0      0            112053  30.0000        S
#         888      1      2        W./C. 6607  23.4500        S
#         889      0      0            111369  30.0000        C
#         890      0      0            370376   7.7500        Q
#
#         [891 rows x 11 columns]
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex        Age  \
# 0                              Braund, Mr. Owen Harris    male  22.000000
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.000000
# 2                               Heikkinen, Miss. Laina  female  26.000000
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.000000
# 4                             Allen, Mr. William Henry    male  35.000000
# ..                                                 ...     ...        ...
# 886                              Montvila, Rev. Juozas    male  27.000000
# 887                       Graham, Miss. Margaret Edith  female  19.000000
# 888           Johnston, Miss. Catherine Helen "Carrie"  female  23.494303
# 889                              Behr, Mr. Karl Howell    male  26.000000
# 890                                Dooley, Mr. Patrick    male  32.000000
#
#      SibSp  Parch            Ticket     Fare Embarked
# 0        1      0         A/5 21171   7.2500        S
# 1        1      0          PC 17599  71.2833        C
# 2        0      0  STON/O2. 3101282   7.9250        S
# 3        1      0            113803  53.1000        S
# 4        0      0            373450   8.0500        S
# ..     ...    ...               ...      ...      ...
# 886      0      0            211536  13.0000        S
# 887      0      0            112053  30.0000        S
# 888      1      2        W./C. 6607  23.4500        S
# 889      0      0            111369  30.0000        C
# 890      0      0            370376   7.7500        Q
#
# [891 rows x 11 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          891 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(4)
# memory usage: 76.7+ KB

# %%
# Forward fill the 'Score' column
df['Embarked'] = df['Embarked'].ffill()
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          891 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Embarked     891 non-null    object
# dtypes: float64(2), int64(5), object(4)
# memory usage: 76.7+ KB

# %%
x_cols = ["PassengerId","Pclass","Sex","SibSp","Parch","Ticket","Fare","Embarked","Age"]

# %%
X = df[x_cols]
X.head()  #These are features which we will use
# Out:
#    PassengerId  Pclass     Sex  SibSp  Parch            Ticket     Fare  \
# 0            1       3    male      1      0         A/5 21171   7.2500
# 1            2       1  female      1      0          PC 17599  71.2833
# 2            3       3  female      0      0  STON/O2. 3101282   7.9250
# 3            4       1  female      1      0            113803  53.1000
# 4            5       3    male      0      0            373450   8.0500
#
#   Embarked   Age
# 0        S  22.0
# 1        C  38.0
# 2        S  26.0
# 3        S  35.0
# 4        S  35.0

# %%
label_encoder = LabelEncoder()
X['Sex'] = label_encoder.fit_transform(X['Sex']).astype(float)

# %%
X.head()
# Out:
#    PassengerId  Pclass  Sex  SibSp  Parch            Ticket     Fare Embarked  \
# 0            1       3  1.0      1      0         A/5 21171   7.2500        S
# 1            2       1  0.0      1      0          PC 17599  71.2833        C
# 2            3       3  0.0      0      0  STON/O2. 3101282   7.9250        S
# 3            4       1  0.0      1      0            113803  53.1000        S
# 4            5       3  1.0      0      0            373450   8.0500        S
#
#     Age
# 0  22.0
# 1  38.0
# 2  26.0
# 3  35.0
# 4  35.0

# %%
X['Embarked'].unique()
# Out:
# array(['S', 'C', 'Q'], dtype=object)

# %%
X['Embarked'] = label_encoder.fit_transform(X["Embarked"]).astype(float)

# %%
X.head()
# Out:
#    PassengerId  Pclass  Sex  SibSp  Parch            Ticket     Fare  \
# 0            1       3  1.0      1      0         A/5 21171   7.2500
# 1            2       1  0.0      1      0          PC 17599  71.2833
# 2            3       3  0.0      0      0  STON/O2. 3101282   7.9250
# 3            4       1  0.0      1      0            113803  53.1000
# 4            5       3  1.0      0      0            373450   8.0500
#
#    Embarked   Age
# 0       2.0  22.0
# 1       0.0  38.0
# 2       2.0  26.0
# 3       2.0  35.0
# 4       2.0  35.0

# %%
X = X.drop("Ticket",axis = 1)

# %%
X
# Out:
#      PassengerId  Pclass  Sex  SibSp  Parch     Fare  Embarked        Age
# 0              1       3  1.0      1      0   7.2500       2.0  22.000000
# 1              2       1  0.0      1      0  71.2833       0.0  38.000000
# 2              3       3  0.0      0      0   7.9250       2.0  26.000000
# 3              4       1  0.0      1      0  53.1000       2.0  35.000000
# 4              5       3  1.0      0      0   8.0500       2.0  35.000000
# ..           ...     ...  ...    ...    ...      ...       ...        ...
# 886          887       2  1.0      0      0  13.0000       2.0  27.000000
# 887          888       1  0.0      0      0  30.0000       2.0  19.000000
# 888          889       3  0.0      1      2  23.4500       2.0  23.494303
# 889          890       1  1.0      0      0  30.0000       0.0  26.000000
# 890          891       3  1.0      0      0   7.7500       1.0  32.000000
#
# [891 rows x 8 columns]

# %% [markdown]
# ### Let's Split the data in features and target:

# %%
correlation_matrix = X[["PassengerId","Pclass","Sex","SibSp","Parch","Fare","Embarked","Age"]].corr()
correlation_matrix
# Out:
#              PassengerId    Pclass       Sex     SibSp     Parch      Fare  \
# PassengerId     1.000000 -0.035144  0.042939 -0.057527 -0.001652  0.012658
# Pclass         -0.035144  1.000000  0.131900  0.083081  0.018443 -0.549500
# Sex             0.042939  0.131900  1.000000 -0.114631 -0.245489 -0.182333
# SibSp          -0.057527  0.083081 -0.114631  1.000000  0.414838  0.159651
# Parch          -0.001652  0.018443 -0.245489  0.414838  1.000000  0.216225
# Fare            0.012658 -0.549500 -0.182333  0.159651  0.216225  1.000000
# Embarked        0.015216  0.168430  0.113807  0.070111  0.041732 -0.228364
# Age             0.041394 -0.405734  0.117450 -0.381055 -0.219961  0.091732
#
#              Embarked       Age
# PassengerId  0.015216  0.041394
# Pclass       0.168430 -0.405734
# Sex          0.113807  0.117450
# SibSp        0.070111 -0.381055
# Parch        0.041732 -0.219961
# Fare        -0.228364  0.091732
# Embarked     1.000000 -0.027922
# Age         -0.027922  1.000000

# %%
correlation_matrix_2d = correlation_matrix.values

# %%
correlation_matrix_2d.shape
# Out:
# (8, 8)

# %%
sb.heatmap(correlation_matrix_2d, annot= True)
plt.show()

# %%
X = X.drop(columns=["Pclass","SibSp","Parch"], axis=1)

# %%
X.head()
# Out:
#    PassengerId  Sex     Fare  Embarked   Age
# 0            1  1.0   7.2500       2.0  22.0
# 1            2  0.0  71.2833       0.0  38.0
# 2            3  0.0   7.9250       2.0  26.0
# 3            4  0.0  53.1000       2.0  35.0
# 4            5  1.0   8.0500       2.0  35.0

# %%
standard_scaler = StandardScaler()
standard_scaler.fit_transform(X)
# Out:
# array([[-1.73010796,  0.73769513, -0.50244517,  0.58904489, -0.5329387 ],
#        [-1.72622007, -1.35557354,  0.78684529, -1.93421952,  0.63382512],
#        [-1.72233219, -1.35557354, -0.48885426,  0.58904489, -0.24124774],
#        ...,
#        [ 1.72233219, -1.35557354, -0.17626324,  0.58904489, -0.42397003],
#        [ 1.72622007,  0.73769513, -0.04438104, -1.93421952, -0.24124774],
#        [ 1.73010796,  0.73769513, -0.49237783, -0.67258731,  0.19628869]])

# %%
y = df["Survived"]

# %%
X.shape
# Out:
# (891, 5)

# %%
y.shape
# Out:
# (891,)

# %%
y.isnull().sum()
# Out:
# 0

# %% [markdown]
# ### Let's split data into testing and training

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size=0.3, random_state=0)

# %%
X_train
# Out:
#      PassengerId  Sex     Fare  Embarked        Age
# 857          858  1.0  26.5500       2.0  51.000000
# 52            53  0.0  76.7292       0.0  49.000000
# 386          387  1.0  46.9000       2.0   1.000000
# 124          125  1.0  77.2875       2.0  54.000000
# 578          579  0.0  14.4583       0.0  25.270837
# ..           ...  ...      ...       ...        ...
# 835          836  0.0  83.1583       0.0  39.000000
# 192          193  0.0   7.8542       2.0  19.000000
# 629          630  1.0   7.7333       1.0  29.081660
# 559          560  0.0  17.4000       2.0  36.000000
# 684          685  1.0  39.0000       2.0  60.000000
#
# [623 rows x 5 columns]

# %%
lr = LogisticRegression()

# %%
lr1 = LogisticRegression(multi_class = "ovr")

# %%
lr2 = LogisticRegression(multi_class = "multinomial")

# %%
lr.fit(X_train, y_train)
# Out:
# LogisticRegression()

# %%
lr1.fit(X_train, y_train)
# Out:
# LogisticRegression(multi_class='ovr')

# %%
lr2.fit(X_train,y_train)
# Out:
# LogisticRegression(multi_class='multinomial')

# %%
pred = lr.predict(X_test)

# %%
pred1 = lr1.predict(X_test)

# %%
pred2 = lr2.predict(X_test)

# %%
accuracy_score(y_test,pred)
# Out:
# 0.7835820895522388

# %%
accuracy_score(y_test,pred1)
# Out:
# 0.7835820895522388

# %%
accuracy_score(y_test,pred2)
# Out:
# 0.7835820895522388

# %%
np.where(y_test!=pred1)
# Out:
# (array([  5,   8,  15,  19,  24,  29,  33,  35,  40,  50,  51,  54,  57,
#          59,  61,  71,  76,  81,  82,  92,  94,  99, 104, 107, 112, 113,
#         114, 120, 127, 130, 133, 137, 143, 145, 152, 156, 157, 158, 161,
#         179, 190, 198, 200, 201, 204, 206, 211, 213, 217, 218, 228, 233,
#         245, 246, 254, 255, 257, 258], dtype=int64),)

# %% [markdown]
# #### Currently getting max accuracy on multinomial model which is 79 which is not good let's do some Feature Engineering to improve our accuracy:

# %%
X
# Out:
#      PassengerId  Sex     Fare  Embarked        Age
# 0              1  1.0   7.2500       2.0  22.000000
# 1              2  0.0  71.2833       0.0  38.000000
# 2              3  0.0   7.9250       2.0  26.000000
# 3              4  0.0  53.1000       2.0  35.000000
# 4              5  1.0   8.0500       2.0  35.000000
# ..           ...  ...      ...       ...        ...
# 886          887  1.0  13.0000       2.0  27.000000
# 887          888  0.0  30.0000       2.0  19.000000
# 888          889  0.0  23.4500       2.0  23.494303
# 889          890  1.0  30.0000       0.0  26.000000
# 890          891  1.0   7.7500       1.0  32.000000
#
# [891 rows x 5 columns]

# %%
# Define age bins and labels
bins = [0, 12, 18, 35, 60, 100]
labels = ['Child', 'Teen', 'Adult', 'Middle Age', 'Senior']

# Create AgeGroup feature
df['AgeGroup'] = pd.cut(df['Age'], bins=bins, labels=labels)

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Embarked    AgeGroup
# 0      0         A/5 21171   7.2500        S       Adult
# 1      0          PC 17599  71.2833        C  Middle Age
# 2      0  STON/O2. 3101282   7.9250        S       Adult
# 3      0            113803  53.1000        S       Adult
# 4      0            373450   8.0500        S       Adult

# %%
df_1 = pd.get_dummies(df["AgeGroup"])
df_1.head()
# Out:
#    Child   Teen  Adult  Middle Age  Senior
# 0  False  False   True       False   False
# 1  False  False  False        True   False
# 2  False  False   True       False   False
# 3  False  False   True       False   False
# 4  False  False   True       False   False

# %%
merged_df = pd.concat([df, df1], axis=1)
merged_df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex        Age  \
# 0                              Braund, Mr. Owen Harris    male  22.000000
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.000000
# 2                               Heikkinen, Miss. Laina  female  26.000000
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.000000
# 4                             Allen, Mr. William Henry    male  35.000000
# ..                                                 ...     ...        ...
# 886                              Montvila, Rev. Juozas    male  27.000000
# 887                       Graham, Miss. Margaret Edith  female  19.000000
# 888           Johnston, Miss. Catherine Helen "Carrie"  female  23.494303
# 889                              Behr, Mr. Karl Howell    male  26.000000
# 890                                Dooley, Mr. Patrick    male  32.000000
#
#      SibSp  Parch            Ticket     Fare Embarked    AgeGroup    A    B
# 0        1      0         A/5 21171   7.2500        S       Adult  1.0  4.0
# 1        1      0          PC 17599  71.2833        C  Middle Age  2.0  5.0
# 2        0      0  STON/O2. 3101282   7.9250        S       Adult  3.0  6.0
# 3        1      0            113803  53.1000        S       Adult  NaN  NaN
# 4        0      0            373450   8.0500        S       Adult  NaN  NaN
# ..     ...    ...               ...      ...      ...         ...  ...  ...
# 886      0      0            211536  13.0000        S       Adult  NaN  NaN
# 887      0      0            112053  30.0000        S       Adult  NaN  NaN
# 888      1      2        W./C. 6607  23.4500        S       Adult  NaN  NaN
# 889      0      0            111369  30.0000        C       Adult  NaN  NaN
# 890      0      0            370376   7.7500        Q       Adult  NaN  NaN
#
# [891 rows x 14 columns]

# %%
#COMMENTS:
#Try to do feature sclaing more now accuracy is 78 but need it 83 by hook or by crook currently I was working on creating merging two dataframes which is AGE Group and df simple
