# %%
import pandas as pd 
import numpy as np

# %%
df = pd.read_csv('Assets/Titanic_Dataset.csv') 
# In this csv, I have added Age column missing value by predicting it through
# linear regression model. Now will merge it to dataset.
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex        Age  \
# 0                              Braund, Mr. Owen Harris    male  22.000000
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.000000
# 2                               Heikkinen, Miss. Laina  female  26.000000
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.000000
# 4                             Allen, Mr. William Henry    male  35.000000
# ..                                                 ...     ...        ...
# ...

# %%
train = pd.read_csv('Assets/titanic/train.csv')

# %%
test = pd.read_csv('Assets/titanic/test.csv')

# %%
train.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
test.head()
# Out:
#    PassengerId  Pclass                                          Name     Sex  \
# 0          892       3                              Kelly, Mr. James    male
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2          894       2                     Myles, Mr. Thomas Francis    male
# 3          895       3                              Wirz, Mr. Albert    male
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
#
#     Age  SibSp  Parch   Ticket     Fare Cabin Embarked
# 0  34.5      0      0   330911   7.8292   NaN        Q
# 1  47.0      1      0   363272   7.0000   NaN        S
# 2  62.0      0      0   240276   9.6875   NaN        Q
# 3  27.0      0      0   315154   8.6625   NaN        S
# 4  22.0      1      1  3101298  12.2875   NaN        S

# %%
train['Age'].count()
# Out:
# 714

# %%
print(train.isna().sum())
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
print(test.isna().sum())
# Out:
# PassengerId      0
# Pclass           0
# Name             0
# Sex              0
# Age             86
# SibSp            0
# Parch            0
# Ticket           0
# Fare             1
# Cabin          327
# Embarked         0
# dtype: int64

# %%
print(df.isna().sum())
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age              0
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
df[['PassengerId','Age']]
# Out:
#      PassengerId        Age
# 0              1  22.000000
# 1              2  38.000000
# 2              3  26.000000
# 3              4  35.000000
# 4              5  35.000000
# ..           ...        ...
# 886          887  27.000000
# 887          888  19.000000
# 888          889  23.494303
# 889          890  26.000000
# 890          891  32.000000
#
# [891 rows x 2 columns]

# %%
df['Age'] = df['Age'].astype('int')
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex  Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male   22      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female   38      1
# 2                               Heikkinen, Miss. Laina  female   26      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female   35      1
# 4                             Allen, Mr. William Henry    male   35      0
# ..                                                 ...     ...  ...    ...
# ...

# %%
train[['PassengerId','Age']]
# Out:
#      PassengerId   Age
# 0              1  22.0
# 1              2  38.0
# 2              3  26.0
# 3              4  35.0
# 4              5  35.0
# ..           ...   ...
# 886          887  27.0
# 887          888  19.0
# 888          889   NaN
# 889          890  26.0
# 890          891  32.0
#
# [891 rows x 2 columns]

# %%
# Drop existing Age column from train and test if it exists
if 'Age' in train.columns:
    train.drop(columns=['Age'], inplace=True)

# Merge Age column from df into train and test dataframes
train_1 = train.merge(df[['PassengerId', 'Age']], on='PassengerId', how='left')

# %%
train_1.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex  SibSp  Parch  \
# 0                            Braund, Mr. Owen Harris    male      1      0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female      1      0
# 2                             Heikkinen, Miss. Laina  female      0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female      1      0
# 4                           Allen, Mr. William Henry    male      0      0
#
#              Ticket     Fare Cabin Embarked  Age
# 0         A/5 21171   7.2500   NaN        S   22
# 1          PC 17599  71.2833   C85        C   38
# 2  STON/O2. 3101282   7.9250   NaN        S   26
# 3            113803  53.1000  C123        S   35
# 4            373450   8.0500   NaN        S   35

# %%
test.head()
# Out:
#    PassengerId  Pclass                                          Name     Sex  \
# 0          892       3                              Kelly, Mr. James    male
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2          894       2                     Myles, Mr. Thomas Francis    male
# 3          895       3                              Wirz, Mr. Albert    male
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
#
#     Age  SibSp  Parch   Ticket     Fare Cabin Embarked
# 0  34.5      0      0   330911   7.8292   NaN        Q
# 1  47.0      1      0   363272   7.0000   NaN        S
# 2  62.0      0      0   240276   9.6875   NaN        Q
# 3  27.0      0      0   315154   8.6625   NaN        S
# 4  22.0      1      1  3101298  12.2875   NaN        S

# %%
test.isna().sum()
# Out:
# PassengerId      0
# Pclass           0
# Name             0
# Sex              0
# Age             86
# SibSp            0
# Parch            0
# Ticket           0
# Fare             1
# Cabin          327
# Embarked         0
# dtype: int64

# %%
train_1.isna().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# Age              0
# dtype: int64

# %%
train_1.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'SibSp', 'Parch',
#        'Ticket', 'Fare', 'Cabin', 'Embarked', 'Age'],
#       dtype='object')

# %%
columnstoremove = ['PassengerId', 'Survived','Ticket','Cabin']

train_1.drop(columns= columnstoremove, axis= 1, inplace= True)

train_1.drop(columns= ['Name'], axis= 1, inplace= True)

# %%
train_1.head()
# Out:
#    Pclass     Sex  SibSp  Parch     Fare Embarked  Age
# 0       3    male      1      0   7.2500        S   22
# 1       1  female      1      0  71.2833        C   38
# 2       3  female      0      0   7.9250        S   26
# 3       1  female      1      0  53.1000        S   35
# 4       3    male      0      0   8.0500        S   35

# %%
train_1.isna().sum()
# Out:
# Pclass      0
# Sex         0
# SibSp       0
# Parch       0
# Fare        0
# Embarked    2
# Age         0
# dtype: int64

# %%
# Fill NaN values in the Embarked column with the mode

mode_embarked = train_1['Embarked'].mode()[0]
train_1['Embarked'] = train_1['Embarked'].fillna(mode_embarked)

# %%
from sklearn.preprocessing import LabelEncoder, StandardScaler

lb = LabelEncoder()
train_1['Sex'] = lb.fit_transform(train_1['Sex'])
train_1['Embarked'] = lb.fit_transform(train_1['Embarked'])

s_c = StandardScaler()
train_1 = s_c.fit_transform(train_1)

# %%
train_1
# Out:
# array([[ 0.82737724,  0.73769513,  0.43279337, ..., -0.50244517,
#          0.58595414, -0.52714991],
#        [-1.56610693, -1.35557354,  0.43279337, ...,  0.78684529,
#         -1.9423032 ,  0.63996441],
#        [ 0.82737724, -1.35557354, -0.4745452 , ..., -0.48885426,
#          0.58595414, -0.23537133],
#        ...,
#        [ 0.82737724, -1.35557354,  0.43279337, ..., -0.17626324,
#          0.58595414, -0.45420527],
#        [-1.56610693,  0.73769513, -0.4745452 , ..., -0.04438104,
#         -1.9423032 , -0.23537133],
#        [ 0.82737724,  0.73769513, -0.4745452 , ..., -0.49237783,
#         -0.67817453,  0.20229654]])

# %%
target = train['Survived']
target
# Out:
# 0      0
# 1      1
# 2      1
# 3      1
# 4      0
#       ..
# 886    0
# 887    1
# 888    0
# 889    1
# 890    0
# Name: Survived, Length: 891, dtype: int64

# %%
from sklearn.ensemble import RandomForestClassifier

rf = RandomForestClassifier(n_estimators=10,random_state=0, criterion='entropy')
rf.fit(train_1, target)
# Out:
# RandomForestClassifier(criterion='entropy', n_estimators=10, random_state=0)

# %%
rf.predict(test)
# Out:
# c:\Users\SHTLP_0060\anaconda3\Lib\site-packages\sklearn\base.py:432: UserWarning: X has feature names, but RandomForestClassifier was fitted without feature names
#   warnings.warn(
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_25032\1363961200.py in ?()
# ----> 1 rf.predict(test)
#
# c:\Users\SHTLP_0060\anaconda3\Lib\site-packages\sklearn\ensemble\_forest.py in ?(self, X)
#     816         -------
#     817         y : ndarray of shape (n_samples,) or (n_samples, n_outputs)
#     818             The predicted classes.
#     819         """
# --> 820         proba = self.predict_proba(X)
#     821
#     822         if self.n_outputs_ == 1:
#     823             return self.classes_.take(np.argmax(proba, axis=1), axis=0)
#
# c:\Users\SHTLP_0060\anaconda3\Lib\site-packages\sklearn\ensemble\_forest.py in ?(self, X)
# ...
